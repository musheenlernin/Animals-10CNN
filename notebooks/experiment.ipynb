# %% [markdown]
# Import statements

# %%
import torch
from torch.utils.data import DataLoader, random_split
from torchvision import transforms
from torchvision.datasets import ImageFolder

# %%
# Since ResNet50 was trained on ImageNet, should resize and normalize accordingly
# Described in "Deep Residual Learning for Image Recognition" https://arxiv.org/abs/1512.03385

data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(10),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val_test': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}

# %%
from torch.utils.data import Subset

# Load dataset
data_dir = '../data/raw-img/' 
datasets = ImageFolder(root=data_dir) # TODO Labels are in Italian and should be translated
class_names = datasets.classes

# Define sizes for validation and test sets
train_size = int(0.7 * len(datasets))  # 70% for training
val_size = int(0.15 * len(datasets))   # 15% for validation
test_size = len(datasets) - train_size - val_size  # Remaining 15% for testing


# Split the val_test dataset into validation and test sets
train_set, val_set, test_set = random_split(datasets, [train_size, val_size, test_size])

# SANITY CHECK
val_set = train_set = Subset(train_set, range(20))

# Apply custom transforms

class TransformedSubset(torch.utils.data.Dataset):
    def __init__(self, subset, transform):
        self.subset = subset
        self.transform = transform

    def __getitem__(self, index):
        image, label = self.subset[index]
        image = self.transform(image)
        return image, label

    def __len__(self):
        return len(self.subset)

datasets = {
    'train' : TransformedSubset(train_set, data_transforms['train']),
    'val' : TransformedSubset(val_set, data_transforms['val_test']),
    'test' : TransformedSubset(test_set, data_transforms['val_test'])
}


# Set batch_size
batch_size = 128

# Create DataLoaders
dataloaders = {
    x: DataLoader(datasets[x], batch_size=batch_size, shuffle=(x == 'train')) for x in ['train', 'val', 'test']
               } # NOTE: Consider setting num_workers (maybe write a script that sets num_workers device independently?)


# dataset sizes
dataset_sizes = {x: len(datasets[x]) for x in ['train', 'val', 'test']}

# %%
dataset_sizes
# Out:
# {'train': 20, 'val': 20, 'test': 3928}

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from torch import nn
from torchvision import models


# Load ResNet50
model = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)

# Freeze earlier layers
for param in model.parameters():
    param.requires_grad = False

# Modify the final layer to match the number of classes in Animals10 (10)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, len(class_names))

model = model.to(device)

# Define loss function and optimizer (only optimizing the last layer)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.fc.parameters(), lr=0.01)

# %%
len([param for param in model.fc.parameters()])
# Out:
# 2

# %%
sum(p.numel() for p in model.parameters() if p.requires_grad)
# Out:
# 20490

# %%
model.named_children
# Out:
# <bound method Module.named_children of ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=10, bias=True)
# )>

# %%
import time
import copy

def train_model(model, criterion, optimizer, num_epochs=10):
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print(f'Epoch {epoch + 1}/{num_epochs}')
        print('-' * 10)

        # Start timing the epoch
        start_time = time.time()

    
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data
            for inputs, labels in dataloaders[phase]:
                inputs, labels = inputs.to(device), labels.to(device)
                print('.', end="")
                # Zero the parameter gradients
                optimizer.zero_grad()

                # Forward pass
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # Backward pass and optimize if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # Statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            print()


            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            # Deep copy the model if the accuracy improves
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        # End timing the epoch
        epoch_time = time.time() - start_time
        print(f'Epoch completed in {epoch_time // 60:.0f}m {epoch_time % 60:.0f}s')

    # Load best model weights
    model.load_state_dict(best_model_wts)
    return model

# Start overall training timer
overall_start_time = time.time()

# Train the model
model = train_model(model, criterion, optimizer, num_epochs=100)

# Calculate total time taken
total_time = time.time() - overall_start_time
print(f'Total training time: {total_time // 60:.0f}m {total_time % 60:.0f}s')

# Save the best model
torch.save(model.state_dict(), 'best_model1.pth')
# Out:
# Epoch 1/100
# ----------
# .
# train Loss: 2.2675 Acc: 0.1500
# .
# val Loss: 1.5519 Acc: 0.7000
# Epoch completed in 0m 3s
# Epoch 2/100
# ----------
# .
# train Loss: 1.1588 Acc: 0.6000
# .
# val Loss: 0.9766 Acc: 0.9500
# Epoch completed in 0m 3s
# Epoch 3/100
# ----------
# .
# train Loss: 0.6956 Acc: 0.8500
# .
# val Loss: 0.5971 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 4/100
# ----------
# .
# train Loss: 0.4289 Acc: 1.0000
# .
# val Loss: 0.3689 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 5/100
# ----------
# .
# train Loss: 0.2172 Acc: 1.0000
# .
# val Loss: 0.2300 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 6/100
# ----------
# .
# train Loss: 0.2307 Acc: 0.9500
# .
# val Loss: 0.1429 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 7/100
# ----------
# .
# train Loss: 0.0985 Acc: 1.0000
# .
# val Loss: 0.0884 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 8/100
# ----------
# .
# train Loss: 0.0618 Acc: 1.0000
# .
# val Loss: 0.0595 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 9/100
# ----------
# .
# train Loss: 0.0987 Acc: 0.9500
# .
# val Loss: 0.0401 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 10/100
# ----------
# .
# train Loss: 0.0503 Acc: 1.0000
# .
# val Loss: 0.0277 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 11/100
# ----------
# .
# train Loss: 0.0113 Acc: 1.0000
# .
# val Loss: 0.0185 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 12/100
# ----------
# .
# train Loss: 0.1923 Acc: 0.9500
# .
# val Loss: 0.0134 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 13/100
# ----------
# .
# train Loss: 0.0039 Acc: 1.0000
# .
# val Loss: 0.0097 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 14/100
# ----------
# .
# train Loss: 0.0039 Acc: 1.0000
# .
# val Loss: 0.0073 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 15/100
# ----------
# .
# train Loss: 0.0028 Acc: 1.0000
# .
# val Loss: 0.0056 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 16/100
# ----------
# .
# train Loss: 0.0278 Acc: 1.0000
# .
# val Loss: 0.0049 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 17/100
# ----------
# .
# train Loss: 0.0280 Acc: 1.0000
# .
# val Loss: 0.0044 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 18/100
# ----------
# .
# train Loss: 0.0541 Acc: 0.9500
# .
# val Loss: 0.0039 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 19/100
# ----------
# .
# train Loss: 0.0124 Acc: 1.0000
# .
# val Loss: 0.0036 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 20/100
# ----------
# .
# train Loss: 0.0026 Acc: 1.0000
# .
# val Loss: 0.0034 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 21/100
# ----------
# .
# train Loss: 0.0019 Acc: 1.0000
# .
# val Loss: 0.0031 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 22/100
# ----------
# .
# train Loss: 0.0104 Acc: 1.0000
# .
# val Loss: 0.0028 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 23/100
# ----------
# .
# train Loss: 0.0081 Acc: 1.0000
# .
# val Loss: 0.0023 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 24/100
# ----------
# .
# train Loss: 0.0016 Acc: 1.0000
# .
# val Loss: 0.0017 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 25/100
# ----------
# .
# train Loss: 0.0066 Acc: 1.0000
# .
# val Loss: 0.0015 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 26/100
# ----------
# .
# train Loss: 0.0008 Acc: 1.0000
# .
# val Loss: 0.0013 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 27/100
# ----------
# .
# train Loss: 0.0005 Acc: 1.0000
# .
# val Loss: 0.0012 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 28/100
# ----------
# .
# train Loss: 0.0005 Acc: 1.0000
# .
# val Loss: 0.0010 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 29/100
# ----------
# .
# train Loss: 0.0004 Acc: 1.0000
# .
# val Loss: 0.0009 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 30/100
# ----------
# .
# train Loss: 0.0022 Acc: 1.0000
# .
# val Loss: 0.0007 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 31/100
# ----------
# .
# train Loss: 0.0061 Acc: 1.0000
# .
# val Loss: 0.0007 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 32/100
# ----------
# .
# train Loss: 0.1216 Acc: 0.9500
# .
# val Loss: 0.0005 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 33/100
# ----------
# .
# train Loss: 0.0012 Acc: 1.0000
# .
# val Loss: 0.0003 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 34/100
# ----------
# .
# train Loss: 0.0015 Acc: 1.0000
# .
# val Loss: 0.0003 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 35/100
# ----------
# .
# train Loss: 0.0726 Acc: 0.9500
# .
# val Loss: 0.0003 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 36/100
# ----------
# .
# train Loss: 0.0919 Acc: 0.9500
# .
# val Loss: 0.0002 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 37/100
# ----------
# .
# train Loss: 0.0004 Acc: 1.0000
# .
# val Loss: 0.0002 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 38/100
# ----------
# .
# train Loss: 0.0011 Acc: 1.0000
# .
# val Loss: 0.0002 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 39/100
# ----------
# .
# train Loss: 0.0012 Acc: 1.0000
# .
# val Loss: 0.0001 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 40/100
# ----------
# .
# train Loss: 0.0115 Acc: 1.0000
# .
# val Loss: 0.0002 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 41/100
# ----------
# .
# train Loss: 0.0001 Acc: 1.0000
# .
# val Loss: 0.0001 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 42/100
# ----------
# .
# train Loss: 0.0002 Acc: 1.0000
# .
# val Loss: 0.0001 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 43/100
# ----------
# .
# train Loss: 0.0003 Acc: 1.0000
# .
# val Loss: 0.0001 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 44/100
# ----------
# .
# train Loss: 0.0017 Acc: 1.0000
# .
# val Loss: 0.0001 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 45/100
# ----------
# .
# train Loss: 0.2123 Acc: 0.9500
# .
# val Loss: 0.0001 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 46/100
# ----------
# .
# train Loss: 0.0004 Acc: 1.0000
# .
# val Loss: 0.0002 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 47/100
# ----------
# .
# train Loss: 0.0542 Acc: 1.0000
# .
# val Loss: 0.0002 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 48/100
# ----------
# .
# train Loss: 0.0071 Acc: 1.0000
# .
# val Loss: 0.0002 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 49/100
# ----------
# .
# train Loss: 0.0030 Acc: 1.0000
# .
# val Loss: 0.0002 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 50/100
# ----------
# .
# train Loss: 0.1198 Acc: 0.9500
# .
# val Loss: 0.0002 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 51/100
# ----------
# .
# train Loss: 0.0191 Acc: 1.0000
# .
# val Loss: 0.0002 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 52/100
# ----------
# .
# train Loss: 0.0489 Acc: 1.0000
# .
# val Loss: 0.0002 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 53/100
# ----------
# .
# train Loss: 0.0381 Acc: 1.0000
# .
# val Loss: 0.0002 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 54/100
# ----------
# .
# train Loss: 0.0007 Acc: 1.0000
# .
# val Loss: 0.0002 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 55/100
# ----------
# .
# train Loss: 0.0210 Acc: 1.0000
# .
# val Loss: 0.0002 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 56/100
# ----------
# .
# train Loss: 0.0137 Acc: 1.0000
# .
# val Loss: 0.0002 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 57/100
# ----------
# .
# train Loss: 0.0002 Acc: 1.0000
# .
# val Loss: 0.0002 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 58/100
# ----------
# .
# train Loss: 0.0013 Acc: 1.0000
# .
# val Loss: 0.0002 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 59/100
# ----------
# .
# train Loss: 0.0015 Acc: 1.0000
# .
# val Loss: 0.0003 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 60/100
# ----------
# .
# train Loss: 0.0004 Acc: 1.0000
# .
# val Loss: 0.0003 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 61/100
# ----------
# .
# train Loss: 0.0001 Acc: 1.0000
# .
# val Loss: 0.0003 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 62/100
# ----------
# .
# train Loss: 0.0005 Acc: 1.0000
# .
# val Loss: 0.0003 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 63/100
# ----------
# .
# train Loss: 0.0093 Acc: 1.0000
# .
# val Loss: 0.0003 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 64/100
# ----------
# .
# train Loss: 0.0020 Acc: 1.0000
# .
# val Loss: 0.0003 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 65/100
# ----------
# .
# train Loss: 0.0015 Acc: 1.0000
# .
# val Loss: 0.0003 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 66/100
# ----------
# .
# train Loss: 0.0008 Acc: 1.0000
# .
# val Loss: 0.0003 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 67/100
# ----------
# .
# train Loss: 0.0799 Acc: 0.9500
# .
# val Loss: 0.0003 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 68/100
# ----------
# .
# train Loss: 0.0047 Acc: 1.0000
# .
# val Loss: 0.0003 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 69/100
# ----------
# .
# train Loss: 0.0164 Acc: 1.0000
# .
# val Loss: 0.0002 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 70/100
# ----------
# .
# train Loss: 0.0013 Acc: 1.0000
# .
# val Loss: 0.0002 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 71/100
# ----------
# .
# train Loss: 0.0001 Acc: 1.0000
# .
# val Loss: 0.0001 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 72/100
# ----------
# .
# train Loss: 0.0153 Acc: 1.0000
# .
# val Loss: 0.0001 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 73/100
# ----------
# .
# train Loss: 0.1235 Acc: 0.9500
# .
# val Loss: 0.0001 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 74/100
# ----------
# .
# train Loss: 0.0846 Acc: 0.9500
# .
# val Loss: 0.0002 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 75/100
# ----------
# .
# train Loss: 0.0174 Acc: 1.0000
# .
# val Loss: 0.0003 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 76/100
# ----------
# .
# train Loss: 0.0062 Acc: 1.0000
# .
# val Loss: 0.0005 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 77/100
# ----------
# .
# train Loss: 0.0039 Acc: 1.0000
# .
# val Loss: 0.0005 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 78/100
# ----------
# .
# train Loss: 0.0001 Acc: 1.0000
# .
# val Loss: 0.0006 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 79/100
# ----------
# .
# train Loss: 0.0053 Acc: 1.0000
# .
# val Loss: 0.0007 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 80/100
# ----------
# .
# train Loss: 0.0093 Acc: 1.0000
# .
# val Loss: 0.0008 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 81/100
# ----------
# .
# train Loss: 0.0097 Acc: 1.0000
# .
# val Loss: 0.0009 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 82/100
# ----------
# .
# train Loss: 0.0008 Acc: 1.0000
# .
# val Loss: 0.0009 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 83/100
# ----------
# .
# train Loss: 0.0004 Acc: 1.0000
# .
# val Loss: 0.0010 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 84/100
# ----------
# .
# train Loss: 0.0047 Acc: 1.0000
# .
# val Loss: 0.0010 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 85/100
# ----------
# .
# train Loss: 0.1415 Acc: 0.9500
# .
# val Loss: 0.0006 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 86/100
# ----------
# .
# train Loss: 0.5079 Acc: 0.9000
# .
# val Loss: 0.0003 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 87/100
# ----------
# .
# train Loss: 0.0025 Acc: 1.0000
# .
# val Loss: 0.0001 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 88/100
# ----------
# .
# train Loss: 0.0001 Acc: 1.0000
# .
# val Loss: 0.0001 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 89/100
# ----------
# .
# train Loss: 0.0011 Acc: 1.0000
# .
# val Loss: 0.0002 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 90/100
# ----------
# .
# train Loss: 0.0245 Acc: 1.0000
# .
# val Loss: 0.0002 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 91/100
# ----------
# .
# train Loss: 0.0036 Acc: 1.0000
# .
# val Loss: 0.0003 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 92/100
# ----------
# .
# train Loss: 0.0160 Acc: 1.0000
# .
# val Loss: 0.0004 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 93/100
# ----------
# .
# train Loss: 0.3426 Acc: 0.9000
# .
# val Loss: 0.0002 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 94/100
# ----------
# .
# train Loss: 0.0012 Acc: 1.0000
# .
# val Loss: 0.0002 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 95/100
# ----------
# .
# train Loss: 0.0918 Acc: 0.9500
# .
# val Loss: 0.0001 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 96/100
# ----------
# .
# train Loss: 0.0015 Acc: 1.0000
# .
# val Loss: 0.0001 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 97/100
# ----------
# .
# train Loss: 0.0430 Acc: 0.9500
# .
# val Loss: 0.0001 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 98/100
# ----------
# .
# train Loss: 0.0002 Acc: 1.0000
# .
# val Loss: 0.0001 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 99/100
# ----------
# .
# train Loss: 0.0015 Acc: 1.0000
# .
# val Loss: 0.0001 Acc: 1.0000
# Epoch completed in 0m 3s
# Epoch 100/100
# ----------
# .
# train Loss: 0.0004 Acc: 1.0000
# .
# val Loss: 0.0002 Acc: 1.0000
# Epoch completed in 0m 3s
# Total training time: 5m 15s

# %%
def evaluate_model(model):
    model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for inputs, labels in dataloaders['test']:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    print(f'Accuracy of the model on the validation images: {100 * correct / total:.2f}%')

# Evaluate the model
evaluate_model(model)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[61], line 17
#      14     print(f'Accuracy of the model on the validation images: {100 * correct / total:.2f}%')
#      16 # Evaluate the model
# ---> 17 evaluate_model(model)
#
# Cell In[61], line 9, in evaluate_model(model)
#       7 for inputs, labels in dataloaders['test']:
#       8     inputs, labels = inputs.to(device), labels.to(device)
# ----> 9     outputs = model(inputs)
#      10     _, predicted = torch.max(outputs.data, 1)
#      11     total += labels.size(0)
#
# File ~/anaconda3/envs/animals-10cnn/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/animals-10cnn/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/anaconda3/envs/animals-10cnn/lib/python3.12/site-packages/torchvision/models/resnet.py:285, in ResNet.forward(self, x)
#     284 def forward(self, x: Tensor) -> Tensor:
# --> 285     return self._forward_impl(x)
#
# File ~/anaconda3/envs/animals-10cnn/lib/python3.12/site-packages/torchvision/models/resnet.py:275, in ResNet._forward_impl(self, x)
#     273 x = self.layer1(x)
#     274 x = self.layer2(x)
# --> 275 x = self.layer3(x)
#     276 x = self.layer4(x)
#     278 x = self.avgpool(x)
#
# File ~/anaconda3/envs/animals-10cnn/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/animals-10cnn/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/anaconda3/envs/animals-10cnn/lib/python3.12/site-packages/torch/nn/modules/container.py:219, in Sequential.forward(self, input)
#     217 def forward(self, input):
#     218     for module in self:
# --> 219         input = module(input)
#     220     return input
#
# File ~/anaconda3/envs/animals-10cnn/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/animals-10cnn/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/anaconda3/envs/animals-10cnn/lib/python3.12/site-packages/torchvision/models/resnet.py:150, in Bottleneck.forward(self, x)
#     147 out = self.bn1(out)
#     148 out = self.relu(out)
# --> 150 out = self.conv2(out)
#     151 out = self.bn2(out)
#     152 out = self.relu(out)
#
# File ~/anaconda3/envs/animals-10cnn/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/animals-10cnn/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/anaconda3/envs/animals-10cnn/lib/python3.12/site-packages/torch/nn/modules/conv.py:458, in Conv2d.forward(self, input)
#     457 def forward(self, input: Tensor) -> Tensor:
# --> 458     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/anaconda3/envs/animals-10cnn/lib/python3.12/site-packages/torch/nn/modules/conv.py:454, in Conv2d._conv_forward(self, input, weight, bias)
#     450 if self.padding_mode != 'zeros':
#     451     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     452                     weight, bias, self.stride,
#     453                     _pair(0), self.dilation, self.groups)
# --> 454 return F.conv2d(input, weight, bias, self.stride,
#     455                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
